# %% [markdown]
# <a href="https://www.kaggle.com/code/mohammadaljermy/cifar-10?scriptVersionId=232190399" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>
